# %% [markdown]
# # Customer Churn Analysis

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import plotly.express as ex
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## Data Loadings

# %%
df=pd.read_csv("C:/Users/sachi/Downloads/WA_Fn-UseC_-Telco-Customer-Churn.csv")
print(df)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 7038           No              Yes         Yes         Yes             Yes
# ...

# %%
# Get categorical columns
cat_cols=[col for col in df.columns if df[col].dtype=='object']
cat_cols
# Out:
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'TotalCharges',
#  'Churn']

# %% [markdown]
# ## Datasets Inforrmations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0            False          False            False           False
# ...

# %%
# Chjange TotalCharges to numeric datatype
df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Display null value rows
df[np.isnan(df['TotalCharges'])]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
# Drop rows where tenure is zero
df=df.drop(labels=df[df['tenure']==0].index,axis=0)
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # Now we perform EDA

# %%
sns.countplot(x='Churn',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
# Datasets is slightly imbalanced.suggest to use sampling techniques to balance the datasets
sns.countplot(x='Churn',hue='gender',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn',hue='SeniorCitizen',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn',hue='Partner',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ### people who doesn't have partner or single person more like to get churn

# %%
sns.countplot(x='Churn',hue='Dependents',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ### People who deosn't have any dependents or single person more ikely to churn if thr customer has a family,all of them prefer to use same service and retention is high.

# %%
sns.countplot(x='Churn',hue='PhoneService',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ### People who have phone service are more likely to churn

# %%
sns.countplot(x='Churn',hue='MultipleLines',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn',hue='InternetService',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ### Those who opted for fibre optics are more likely to churn, those who DSL service have more retention .

# %%
sns.countplot(x='Churn',hue='OnlineSecurity',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ### People who doesn't have online security are more likely to churn

# %%
sns.countplot(x='Churn',hue='TechSupport',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ### People who doesn't have Tech support are more likely to churn

# %%
sns.countplot(x='Churn',hue='StreamingMovies',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn',hue='Contract',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ### People whoe are monthly contract more likely to churn and people who are on yearly contract less likely to churn.

# %%
sns.countplot(x='Churn',hue='PaperlessBilling',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn',hue='PaymentMethod',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ### People who opted more electronic check payment method are more likely to churn.

# %%
sns.violinplot(x='Churn',y='MonthlyCharges',data=df,color='red')
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %% [markdown]
# ### People who have monthly charges are more likely to churn.

# %%
sns.violinplot(x='Churn',y='tenure',data=df,color='red')
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %% [markdown]
# ### Poeple who are on low tenure or who have subscribed for less no. of months are more likely to churn.

# %%
sns.boxplot(x='Churn',y='tenure',data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %%
fig,axes=plt.subplots(1,2,figsize=(14,6))
sns.kdeplot(df['MonthlyCharges'],ax=axes[0],color='blue',shade=True)
sns.kdeplot(df['TotalCharges'],ax=axes[1],color='red',shade=True)
# Out:
# <Axes: xlabel='TotalCharges', ylabel='Density'>

# %% [markdown]
# ### Correlation Matrix

# %%
plt.figure(figsize=(13,8))
corr=df.apply(lambda x:pd.factorize(x)[0]).corr()
mask=np.triu(np.ones_like(corr,dtype=bool))
sns.heatmap(corr,mask=mask,cmap='coolwarm',vmax=1,vmin=-1,center=0,annot=True,fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# ## Label Encoder

# %%
df.head(2)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0              Yes  Electronic check           29.85         29.85    No
# 1               No      Mailed check           56.95       1889.50    No

# %%
cols=[col for col in df.columns if df[col].dtype=='object']
cols
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
fig,axes=plt.subplots(1,2,figsize=(14,6))
sns.kdeplot(df['MonthlyCharges'],ax=axes[0],color='blue',shade=True)
sns.kdeplot(df['TotalCharges'],ax=axes[1],color='red',shade=True)
# Out:
# <Axes: xlabel='TotalCharges', ylabel='Density'>
